# %% [markdown]
# # ROCK VS MINE

# %% [markdown]
# In this Project, we are building a system in Python that can predict whether an object is either Rock or Mine with SONAR Data.

# %% [markdown]
# MACHINE LEARNING ALGORITHMS :

# %% [markdown]
# 1. LOGISTIC REGRESSION
# 2. DECISION TREE
# 3. RANDOM FOREST
# 4. K-NEAREST NEIGHBOURS
# 5. SUPPORT VECTOR MACHINE
# 6. ADABooST

# %% [markdown]
# IMPORTING DEPENDENCIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# DATA COLLECTION AND DATA PROCESSING

# %%
#loading the data frames 

sonar_data=pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\DATA ANALYSIS PROJECT\sonar data.csv", header=None)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
#number of rows and columns

sonar_data.shape
# Out:
# (208, 61)

# %%
# for some statistical data
sonar_data.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
#to count how many rock and mine objects are there in
sonar_data[60].value_counts()  #60 is writen because whether the object is rock or mine is given in 60th column
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %%
sns.countplot(x=60,data=sonar_data)
# Out:
# <AxesSubplot:xlabel='60', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(sonar_data.isnull())
# Out:
# <AxesSubplot:>

# %%
#visualization dataset also checking for outliers

fig, ax=plt.subplots(ncols=5,nrows=2,figsize=(20,10))
ax=ax.flatten()

index=0

for col,values in sonar_data.items():
    sns.boxplot(y=col,data=sonar_data,ax=ax[index])
    index +=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-2f5bd57c9a25> in <module>
#       7
#       8 for col,values in sonar_data.items():
# ----> 9     sns.boxplot(y=col,data=sonar_data,ax=ax[index])
#      10     index +=1
#
# IndexError: index 10 is out of bounds for axis 0 with size 10

# %%
plt.figure(figsize=(12,8))
sns.heatmap(sonar_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sonar_data.isnull().mean().plot.bar(figsize=(12,8))
plt.xlabel("FEATURES")
plt.ylabel("PERCENTAGE OF MISSING VALUES")

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
#seperating data and labels

x=sonar_data.drop(columns=60,axis=1)
y=sonar_data[60]

# %%
print(x)
print(y)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %% [markdown]
# TRAINING AND TEST DATA

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,stratify=y,random_state=1)

# here,
# test_size=0.1 means we need 10% of the data as test data
# stratify=Y means data will be split according to two parameters here that is rock and mine
#random_state=1 means to split data in particular way

# %%
print(x.shape,x_train.shape,x_test.shape) # here we have total 208 data out of which 187 is for training data and rest 21 for test data
# Out:
# (208, 60) (187, 60) (21, 60)

# %%
print(x_train)
print(y_train)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 115  0.0414  0.0436  0.0447  0.0844  0.0419  0.1215  0.2002  0.1516  0.0818
# 38   0.0123  0.0022  0.0196  0.0206  0.0180  0.0492  0.0033  0.0398  0.0791
# 56   0.0152  0.0102  0.0113  0.0263  0.0097  0.0391  0.0857  0.0915  0.0949
# 123  0.0270  0.0163  0.0341  0.0247  0.0822  0.1256  0.1323  0.1584  0.2017
# 18   0.0270  0.0092  0.0145  0.0278  0.0412  0.0757  0.1026  0.1138  0.0794
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 140  0.0412  0.1135  0.0518  0.0232  0.0646  0.1124  0.1787  0.2407  0.2682
# 5    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 154  0.0117  0.0069  0.0279  0.0583  0.0915  0.1267  0.1577  0.1927  0.2361
# 131  0.1150  0.1163  0.0866  0.0358  0.0232  0.1267  0.2417  0.2661  0.4346
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
#
# ...

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

#object
model_lr=LogisticRegression()

# %%
#Training of the model

model_lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#making prediction
pred_lr=model_lr.predict(x_test)

# %%
#accuracy score

accuracy_score_lr=accuracy_score(y_test,pred_lr)
accuracy_score_lr*100
# Out:
# 76.19047619047619

# %%
cm1=confusion_matrix(y_test,pred_lr)
cm1
# Out:
# array([[9, 2],
#        [3, 7]], dtype=int64)

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

#creating the model object
model_dt=DecisionTreeClassifier(max_depth=4)

# %%
#Training of decision tree

model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
#Making prediction using Decision Tree

pred_dt=model_dt.predict(x_test)

# %%
accuracy_score_dt=accuracy_score(y_test,pred_dt)
accuracy_score_dt*100
# Out:
# 71.42857142857143

# %%
#confusion matrix

cm2=confusion_matrix(y_test,pred_dt)
cm2
# Out:
# array([[9, 2],
#        [4, 6]], dtype=int64)

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

#creating the model object
model_rf=RandomForestClassifier(max_depth=4)

# %%
#training the model

model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=4)

# %%
#making predictions

pred_rf = model_rf.predict(x_test)

# %%
accuracy_score_rf=accuracy_score(y_test,pred_dt)
accuracy_score_rf*100
# Out:
# 71.42857142857143

# %%
cm3=confusion_matrix(y_test,pred_rf)
cm3
# Out:
# array([[9, 2],
#        [3, 7]], dtype=int64)

# %% [markdown]
# # K-NEIGHBOURS (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

#creating model object
model_knn=KNeighborsClassifier()

# %%
for i in range(4,12):
    model_knn=KNeighborsClassifier(n_neighbors=i)
    model_knn.fit(x_train,y_train)
    pred_knn=model_knn.predict(x_test)
    accuracy_score_knn=accuracy_score(y_test,pred_knn)
    print(i,accuracy_score_knn)
# Out:
# 4 0.7619047619047619
# 5 0.8095238095238095
# 6 0.7142857142857143
# 7 0.7619047619047619
# 8 0.7619047619047619
# 9 0.6666666666666666
# 10 0.7142857142857143
# 11 0.7142857142857143

# %%
model_knn=KNeighborsClassifier(n_neighbors=11)
model_knn.fit(x_train,y_train)
pred_knn=model_knn.predict(x_test)
accuracy_score_knn=accuracy_score(y_test,pred_knn)
print(accuracy_score_knn*100)
# Out:
# 71.42857142857143

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC

#creating object of model
model_svm=SVC(kernel="rbf")

# %%
#model training

model_svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
#make prediction

pred_svm=model_svm.predict(x_test)

# %%
accuracy_score_svm=accuracy_score(y_test,pred_svm)
accuracy_score_svm*100
# Out:
# 80.95238095238095

# %% [markdown]
# # ADABOOST CLASSIFIER

# %%
from sklearn.ensemble import AdaBoostClassifier

#making object of model
model_ada=AdaBoostClassifier(n_estimators=200,learning_rate=0.03)

# %%
#Training of the model
model_ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.03, n_estimators=200)

# %%
#making prediction
pred_ada=model_ada.predict(x_test)

# %%
#accuracy check 
accuracy_score_ada=accuracy_score(y_test,pred_ada)
accuracy_score_ada*100
# Out:
# 76.19047619047619

# %%
import pandas as pd

data1 = {
  "MODEL": ["Logistic Regression","Decision Tree","Random Forest","KNN ","SVM","AdaBoost"],
  "ACCURATE SCORE": [accuracy_score_lr,accuracy_score_dt,accuracy_score_rf,accuracy_score_knn,accuracy_score_svm,accuracy_score_ada]
}

#load data into a DataFrame object:
df = pd.DataFrame(data1)

print(df)
# Out:
#                  MODEL  ACCURATE SCORE
# 0  Logistic Regression        0.761905
# 1        Decision Tree        0.714286
# 2        Random Forest        0.714286
# 3                 KNN         0.714286
# 4                  SVM        0.809524
# 5             AdaBoost        0.761905

# %%
sns.barplot(x="ACCURATE SCORE",y="MODEL",data=data1)
data1.sort_values(by="ACCURATE SCORE",ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-5ae507a20a01> in <module>
#       1 sns.barplot(x="ACCURATE SCORE",y="MODEL",data=data1)
# ----> 2 data1.sort_values(by="ACCURATE SCORE",ascending=False)
#
# AttributeError: 'dict' object has no attribute 'sort_values'
